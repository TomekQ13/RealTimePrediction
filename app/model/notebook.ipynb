# %%
import pandas as pd
import json
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train['Sex'].replace({'male': 0, 'female':1}, inplace = True)
train = train[train['Age'].isnull() == False]
train = train[train['Embarked'].isnull() == False]
train = pd.concat([train,  pd.get_dummies(train['Embarked'], prefix = 'Embarked')], axis=1)

# %%
train.drop(columns=['Name', 'Ticket' ,'Cabin', 'Embarked', 'Embarked_C', 'PassengerId'], inplace = True)

# %%
scaling_params = {
    'age_std': train['Age'].std(),
    'age_mean': train['Age'].mean(),
    'fare_std': train['Fare'].std(),
    'fare_mean': train['Fare'].mean()    
}

# %%
with open('scaling_params.json', 'w') as result:
    json.dump(scaling_params, result)

# %%
train['Age'] = (train['Age'] - scaling_params['age_std'])/scaling_params['age_mean']
train['Fare'] = (train['Fare'] - scaling_params['fare_std'])/scaling_params['fare_mean']

# %%
y = train['Survived'].copy()
X = train.drop(columns='Survived')

# %%
train
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked_Q  \
# 0           0       3    0  0.253257      1      0 -1.321732           0
# 1           1       1    1  0.793030      1      0  0.530695           0
# 2           1       3    1  0.388200      0      0 -1.302205           0
# 3           1       1    1  0.691823      1      0  0.004668           0
# 4           0       3    0  0.691823      0      0 -1.298589           0
# ..        ...     ...  ...       ...    ...    ...       ...         ...
# 885         0       3    1  0.826766      0      5 -0.688908           1
# 886         0       2    0  0.421936      0      0 -1.155390           0
# 887         1       1    1  0.152050      0      0 -0.663595           0
# 889         1       1    0  0.388200      0      0 -0.663595           0
# 890         0       3    0  0.590615      0      0 -1.307268           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ..          ...
# 885           0
# 886           1
# 887           1
# 889           0
# 890           0
#
# [712 rows x 9 columns]

# %%
classifier = RandomForestClassifier()

# %%
classifier.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
from modelLoaderSaver import modelLoaderSaver
saver = modelLoaderSaver(classifier)
saver.save('model_params.txt')
# Out:
# Class instance RandomForestClassifier() saved into model_params.txt.

# %%
from modelLoaderSaver import modelLoaderSaver
from sklearn.ensemble import RandomForestClassifier
from numpy import array, int64
from sklearn.tree import DecisionTreeClassifier

classifier2 = RandomForestClassifier()
loader = modelLoaderSaver(classifier2)

loader.load('model_params.txt')
# Out:
# {'base_estimator': DecisionTreeClassifier(), 'n_estimators': 100, 'estimator_params': ('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'random_state', 'ccp_alpha'), 'bootstrap': True, 'oob_score': False, 'n_jobs': None, 'random_state': None, 'verbose': 0, 'warm_start': False, 'class_weight': None, 'max_samples': None, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'ccp_alpha': 0.0, 'n_features_in_': 8, 'n_features_': 8, 'n_outputs_': 1, 'classes_': array([0, 1], dtype=int64), 'n_classes_': 2, 'base_estimator_': DecisionTreeClassifier(), 'estimators_': [DecisionTreeClassifier(max_features='auto', random_state=473350014), DecisionTreeClassifier(max_features='auto', random_state=1109665629), DecisionTreeClassifier(max_features='auto', random_state=2060594794), DecisionTreeClassifier(max_features='auto', random_state=240156838), DecisionTreeClassifier(max_features='auto', random_state=371852419), DecisionTreeClassifier(max_features='auto', random_state=236789698), DecisionTreeClassifier(max_features='auto', random_state=1168488307), DecisionTreeClassifier(max_features='auto', random_state=996008363), DecisionTreeClassifier(max_features='auto', random_state=1050567541), DecisionTreeClassifier(max_features='auto', random_state=1288206701), DecisionTreeClassifier(max_features='auto', random_state=1615548857), DecisionTreeClassifier(max_features='auto', random_state=1623459970), DecisionTreeClassifier(max_features='auto', random_state=1151283954), DecisionTreeClassifier(max_features='auto', random_state=503673900), DecisionTreeClassifier(max_features='auto', random_state=1856477358), DecisionTreeClassifier(max_features='auto', random_state=2020481326), DecisionTreeClassifier(max_features='auto', random_state=363791368), DecisionTreeClassifier(max_features='auto', random_state=671350304), DecisionTreeClassifier(max_features='auto', random_state=819163519), DecisionTreeClassifier(max_features='auto', random_state=1683725100), DecisionTreeClassifier(max_features='auto', random_state=955713396), DecisionTreeClassifier(max_features='auto', random_state=744023693), DecisionTreeClassifier(max_features='auto', random_state=366795450), DecisionTreeClassifier(max_features='auto', random_state=1596768290), DecisionTreeClassifier(max_features='auto', random_state=1162509679), DecisionTreeClassifier(max_features='auto', random_state=1530464634), DecisionTreeClassifier(max_features='auto', random_state=968098708), DecisionTreeClassifier(max_features='auto', random_state=1991852207), DecisionTreeClassifier(max_features='auto', random_state=2013029581), DecisionTreeClassifier(max_features='auto', random_state=459703236), DecisionTreeClassifier(max_features='auto', random_state=290310130), DecisionTreeClassifier(max_features='auto', random_state=95779214), DecisionTreeClassifier(max_features='auto', random_state=1614034170), DecisionTreeClassifier(max_features='auto', random_state=2094515226), DecisionTreeClassifier(max_features='auto', random_state=2006964323), DecisionTreeClassifier(max_features='auto', random_state=1897067593), DecisionTreeClassifier(max_features='auto', random_state=707028120), DecisionTreeClassifier(max_features='auto', random_state=604108993), DecisionTreeClassifier(max_features='auto', random_state=1220846110), DecisionTreeClassifier(max_features='auto', random_state=1501005160), DecisionTreeClassifier(max_features='auto', random_state=1358906033), DecisionTreeClassifier(max_features='auto', random_state=2087247829), DecisionTreeClassifier(max_features='auto', random_state=1352971811), DecisionTreeClassifier(max_features='auto', random_state=289196286), DecisionTreeClassifier(max_features='auto', random_state=1101927169), Deci ...
# Traceback (most recent call last):
#
#   File "C:\Users\kucza\.virtualenvs\RealTimePrediction-dV3zGKUT\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-83-3516955ba7b6>", line 9, in <module>
#     loader.load('model_params.txt')
#
#   File "C:\Users\kucza\OneDrive\Desktop\Projects\RealTimePrediction\app\model\modelLoaderSaver.py", line 26, in load
#     raise e
#
#   File "C:\Users\kucza\OneDrive\Desktop\Projects\RealTimePrediction\app\model\modelLoaderSaver.py", line 23, in load
#     self.class_object.__dict__ = ast.literal_eval(line)
#
#   File "c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py", line 59, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import ast

# %%
with open('model_params.txt', 'r') as file:
     for line in file:
        my_dict = line

# %%
type(my_dict)
# Out:
# str

# %%
my_dict
# Out:
# "{'base_estimator': DecisionTreeClassifier(), 'n_estimators': 100, 'estimator_params': ('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'random_state', 'ccp_alpha'), 'bootstrap': True, 'oob_score': False, 'n_jobs': None, 'random_state': None, 'verbose': 0, 'warm_start': False, 'class_weight': None, 'max_samples': None, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'ccp_alpha': 0.0, 'n_features_in_': 8, 'n_features_': 8, 'n_outputs_': 1, 'classes_': array([0, 1], dtype=int64), 'n_classes_': 2, 'base_estimator_': DecisionTreeClassifier(), 'estimators_': [DecisionTreeClassifier(max_features='auto', random_state=473350014), DecisionTreeClassifier(max_features='auto', random_state=1109665629), DecisionTreeClassifier(max_features='auto', random_state=2060594794), DecisionTreeClassifier(max_features='auto', random_state=240156838), DecisionTreeClassifier(max_features='auto', random_state=371852419), DecisionTreeClassifier(max_features='auto', random_state=236789698), DecisionTreeClassifier(max_features='auto', random_state=1168488307), DecisionTreeClassifier(max_features='auto', random_state=996008363), DecisionTreeClassifier(max_features='auto', random_state=1050567541), DecisionTreeClassifier(max_features='auto', random_state=1288206701), DecisionTreeClassifier(max_features='auto', random_state=1615548857), DecisionTreeClassifier(max_features='auto', random_state=1623459970), DecisionTreeClassifier(max_features='auto', random_state=1151283954), DecisionTreeClassifier(max_features='auto', random_state=503673900), DecisionTreeClassifier(max_features='auto', random_state=1856477358), DecisionTreeClassifier(max_features='auto', random_state=2020481326), DecisionTreeClassifier(max_features='auto', random_state=363791368), DecisionTreeClassifier(max_features='auto', random_state=671350304), DecisionTreeClassifier(max_features='auto', random_state=819163519), DecisionTreeClassifier(max_features='auto', random_state=1683725100), DecisionTreeClassifier(max_features='auto', random_state=955713396), DecisionTreeClassifier(max_features='auto', random_state=744023693), DecisionTreeClassifier(max_features='auto', random_state=366795450), DecisionTreeClassifier(max_features='auto', random_state=1596768290), DecisionTreeClassifier(max_features='auto', random_state=1162509679), DecisionTreeClassifier(max_features='auto', random_state=1530464634), DecisionTreeClassifier(max_features='auto', random_state=968098708), DecisionTreeClassifier(max_features='auto', random_state=1991852207), DecisionTreeClassifier(max_features='auto', random_state=2013029581), DecisionTreeClassifier(max_features='auto', random_state=459703236), DecisionTreeClassifier(max_features='auto', random_state=290310130), DecisionTreeClassifier(max_features='auto', random_state=95779214), DecisionTreeClassifier(max_features='auto', random_state=1614034170), DecisionTreeClassifier(max_features='auto', random_state=2094515226), DecisionTreeClassifier(max_features='auto', random_state=2006964323), DecisionTreeClassifier(max_features='auto', random_state=1897067593), DecisionTreeClassifier(max_features='auto', random_state=707028120), DecisionTreeClassifier(max_features='auto', random_state=604108993), DecisionTreeClassifier(max_features='auto', random_state=1220846110), DecisionTreeClassifier(max_features='auto', random_state=1501005160), DecisionTreeClassifier(max_features='auto', random_state=1358906033), DecisionTreeClassifier(max_features='auto', random_state=2087247829), DecisionTreeClassifier(max_features='auto', random_state=1352971811), DecisionTreeClassifier(max_features='auto', random_state=289196286), DecisionTreeClassifier(max_features='auto', random_state=1101927169), Dec ...

# %%
eval(my_dict)
# Out:
# {'base_estimator': DecisionTreeClassifier(),
#  'n_estimators': 100,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'min_impurity_split',
#   'random_state',
#   'ccp_alpha'),
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'ccp_alpha': 0.0,
#  'n_features_in_': 8,
#  'n_features_': 8,
#  'n_outputs_': 1,
#  'classes_': array([0, 1], dtype=int64),
#  'n_classes_': 2,
#  'base_estimator_': DecisionTreeClassifier(),
#  'estimators_': [DecisionTreeClassifier(max_features='auto', random_state=473350014),
#   DecisionTreeClassifier(max_features='auto', random_state=1109665629),
#   DecisionTreeClassifier(max_features='auto', random_state=2060594794),
#   DecisionTreeClassifier(max_features='auto', random_state=240156838),
#   DecisionTreeClassifier(max_features='auto', random_state=371852419),
#   DecisionTreeClassifier(max_features='auto', random_state=236789698),
#   DecisionTreeClassifier(max_features='auto', random_state=1168488307),
#   DecisionTreeClassifier(max_features='auto', random_state=996008363),
#   DecisionTreeClassifier(max_features='auto', random_state=1050567541),
#   DecisionTreeClassifier(max_features='auto', random_state=1288206701),
#   DecisionTreeClassifier(max_features='auto', random_state=1615548857),
#   DecisionTreeClassifier(max_features='auto', random_state=1623459970),
#   DecisionTreeClassifier(max_features='auto', random_state=1151283954),
#   DecisionTreeClassifier(max_features='auto', random_state=503673900),
#   DecisionTreeClassifier(max_features='auto', random_state=1856477358),
#   DecisionTreeClassifier(max_features='auto', random_state=2020481326),
#   DecisionTreeClassifier(max_features='auto', random_state=363791368),
#   DecisionTreeClassifier(max_features='auto', random_state=671350304),
#   DecisionTreeClassifier(max_features='auto', random_state=819163519),
#   DecisionTreeClassifier(max_features='auto', random_state=1683725100),
#   DecisionTreeClassifier(max_features='auto', random_state=955713396),
#   DecisionTreeClassifier(max_features='auto', random_state=744023693),
#   DecisionTreeClassifier(max_features='auto', random_state=366795450),
#   DecisionTreeClassifier(max_features='auto', random_state=1596768290),
#   DecisionTreeClassifier(max_features='auto', random_state=1162509679),
#   DecisionTreeClassifier(max_features='auto', random_state=1530464634),
#   DecisionTreeClassifier(max_features='auto', random_state=968098708),
#   DecisionTreeClassifier(max_features='auto', random_state=1991852207),
#   DecisionTreeClassifier(max_features='auto', random_state=2013029581),
#   DecisionTreeClassifier(max_features='auto', random_state=459703236),
#   DecisionTreeClassifier(max_features='auto', random_state=290310130),
#   DecisionTreeClassifier(max_features='auto', random_state=95779214),
#   DecisionTreeClassifier(max_features='auto', random_state=1614034170),
#   DecisionTreeClassifier(max_features='auto', random_state=2094515226),
#   DecisionTreeClassifier(max_features='auto', random_state=2006964323),
#   DecisionTreeClassifier(max_features='auto', random_state=1897067593),
#   DecisionTreeClassifier(max_features='auto', random_state=707028120),
#   DecisionTreeClassifier(max_features='auto', random_state=604108993),
#   DecisionTreeClassifier(max_features='auto', random_state=1220846110),
#   DecisionTreeClassifier(max_features='auto', random_state=1501005160),
#   DecisionTreeClassifier(max_features='auto', random_state=1358906033),
#   DecisionTreeClassifier(max_features='auto', random_state=2087247829),
#   DecisionTreeClassifier(max_features='auto', random_state=1352971811),
#   DecisionTreeClassifier(max_features='auto', random_state=289196286),
#   DecisionTreeClassifier(max_features='auto', random_state=1101927169),
#   DecisionTreeClassifier(max_features='auto', random_state=1472755386),
#   DecisionTreeClassifier(max_features='auto', random_state=506497657),
#   DecisionTreeClassifier(max_features='auto', random_state=697108691),
#   DecisionTreeClassifier(max_features='auto', random_state=354036372),
#   DecisionTreeClassifier(max_features='auto', random_state=260853349),
#   DecisionTreeClassifier(max_features='auto', random_state=602530326),
#   DecisionTreeClassifier(max_features='auto', random_state=523083368),
#   DecisionTreeClassifier(max_features='auto', random_state=404440618),
#   DecisionTreeClassifier(max_features='auto', random_state=976351271),
#   DecisionTreeClassifier(max_features='auto', random_state=979922613),
#   DecisionTreeClassifier(max_features='auto', random_state=1200618791),
#   DecisionTreeClassifier(max_features='auto', random_state=598375328),
#   DecisionTreeClassifier(max_features='auto', random_state=1784120651),
#   DecisionTreeClassifier(max_features='auto', random_state=1012202061),
#   DecisionTreeClassifier(max_features='auto', random_state=1741003496),
#   DecisionTreeClassifier(max_features='auto', random_state=1006694898),
#   DecisionTreeClassifier(max_features='auto', random_state=32356586),
#   DecisionTreeClassifier(max_features='auto', random_state=1624038603),
#   DecisionTreeClassifier(max_features='auto', random_state=533501727),
#   DecisionTreeClassifier(max_features='auto', random_state=543018667),
#   DecisionTreeClassifier(max_features='auto', random_state=279870927),
#   DecisionTreeClassifier(max_features='auto', random_state=1111339807),
#   DecisionTreeClassifier(max_features='auto', random_state=1090881695),
#   DecisionTreeClassifier(max_features='auto', random_state=1636951629),
#   DecisionTreeClassifier(max_features='auto', random_state=1788015503),
#   DecisionTreeClassifier(max_features='auto', random_state=128034257),
#   DecisionTreeClassifier(max_features='auto', random_state=1786651448),
#   DecisionTreeClassifier(max_features='auto', random_state=1923663199),
#   DecisionTreeClassifier(max_features='auto', random_state=188977972),
#   DecisionTreeClassifier(max_features='auto', random_state=1321428270),
#   DecisionTreeClassifier(max_features='auto', random_state=1590726629),
#   DecisionTreeClassifier(max_features='auto', random_state=37734424),
#   DecisionTreeClassifier(max_features='auto', random_state=817378170),
#   DecisionTreeClassifier(max_features='auto', random_state=1523721000),
#   DecisionTreeClassifier(max_features='auto', random_state=248690906),
#   DecisionTreeClassifier(max_features='auto', random_state=1373104263),
#   DecisionTreeClassifier(max_features='auto', random_state=80890634),
#   DecisionTreeClassifier(max_features='auto', random_state=264188298),
#   DecisionTreeClassifier(max_features='auto', random_state=964546675),
#   DecisionTreeClassifier(max_features='auto', random_state=863519311),
#   DecisionTreeClassifier(max_features='auto', random_state=197348104),
#   DecisionTreeClassifier(max_features='auto', random_state=1366576347),
#   DecisionTreeClassifier(max_features='auto', random_state=697202823),
#   DecisionTreeClassifier(max_features='auto', random_state=1065455009),
#   DecisionTreeClassifier(max_features='auto', random_state=2007647042),
#   DecisionTreeClassifier(max_features='auto', random_state=1647223800),
#   DecisionTreeClassifier(max_features='auto', random_state=1676159619),
#   DecisionTreeClassifier(max_features='auto', random_state=1736197973),
#   DecisionTreeClassifier(max_features='auto', random_state=370127083),
#   DecisionTreeClassifier(max_features='auto', random_state=998276811),
#   DecisionTreeClassifier(max_features='auto', random_state=1791549098),
#   DecisionTreeClassifier(max_features='auto', random_state=605696741),
#   DecisionTreeClassifier(max_features='auto', random_state=1170153117),
#   DecisionTreeClassifier(max_features='auto', random_state=1328371677),
#   DecisionTreeClassifier(max_features='auto', random_state=259107910)]}

# %%
ast.literal_eval(my_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-6540eb926d52> in <module>
# ----> 1 ast.literal_eval(my_dict)
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in literal_eval(node_or_string)
#      97                     return left - right
#      98         return _convert_signed_num(node)
# ---> 99     return _convert(node_or_string)
#     100
#     101
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in _convert(node)
#      86             if len(node.keys) != len(node.values):
#      87                 _raise_malformed_node(node)
# ---> 88             return dict(zip(map(_convert, node.keys),
#      89                             map(_convert, node.values)))
#      90         elif isinstance(node, BinOp) and isinstance(node.op, (Add, Sub)):
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in _convert(node)
#      96                 else:
#      97                     return left - right
# ---> 98         return _convert_signed_num(node)
#      99     return _convert(node_or_string)
#     100
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in _convert_signed_num(node)
#      73             else:
#      74                 return - operand
# ---> 75         return _convert_num(node)
#      76     def _convert(node):
#      77         if isinstance(node, Constant):
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in _convert_num(node)
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 66             _raise_malformed_node(node)
#      67         return node.value
#      68     def _convert_signed_num(node):
#
# c:\users\kucza\appdata\local\programs\python\python38\lib\ast.py in _raise_malformed_node(node)
#      61         node_or_string = node_or_string.body
#      62     def _raise_malformed_node(node):
# ---> 63         raise ValueError(f'malformed node or string: {node!r}')
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
#
# ValueError: malformed node or string: <_ast.Call object at 0x000001C0FF86F7F0>
